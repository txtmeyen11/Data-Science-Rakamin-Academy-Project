# %% [markdown]
# # Pengenalan Conditional Statement

# %%
import pandas as pd
monthly_order = pd.read_csv(r'F:\COURSE\RAKAMIN\WEEK 6\monthly_rakamin_customer_order.csv')
monthly_order
# Out:
#     order_month       full_name   user_id         phone           city  \
# 0    2018-01-01   Ahmad Budiman  10000011  628785222211  Jakarta Pusat
# 1    2018-01-01      Azzam Haqq  10000012  628785222212       Surabaya
# 2    2018-01-01    Amrina Putri  10000013  628785222213  Jakarta Pusat
# 3    2018-01-01       Aan Utama  10000014  628785222214          Medan
# 4    2018-01-01        Adam Adi  10000015  628785222215  Jakarta Timur
# ..          ...             ...       ...           ...            ...
# 332  2022-06-01       Faruq Adi  10000030  628567812319       Makassar
# 333  2022-06-01       Abrar Adi  10000053  628223411218       Surabaya
# 334  2022-06-01    Johan Imawan  10000054  628223412323     Balikpapan
# 335  2022-06-01  Muhammad Ammar  10000055  628223412111       Surabaya
# 336  2022-05-01  Dodo Putro Aji  10000023  628567812312       Surabaya
#
#              province                   email  total_order  total_gmv  \
# ...

# %%
if monthly_order['total_order'] > 50:
    category ='potential buyer'
else:
    monthly_order
                 category = 'not potential buyer'
print(category)
# Out:
#   File "C:\Users\windows\AppData\Local\Temp\ipykernel_5540\293497944.py", line 5
#     category = 'not potential buyer'
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Buatlah syntax IF untuk melakukan pengecekan apakah plat nomor kendaraan B 1256 AE masuk plat genap atau ganjil !

# %%
plat = 'B 1256 AE'
plat_motor = int(plat.split()[1])
plat_motor
# Out:
# 1256

# %%
if plat_motor%2==0:
    result = 'genap'
else:
    result  = 'ganjil'
print(result)
# Out:
# genap

# %% [markdown]
# Untuk menjadi seller premium seorang seller perlu memenuhi syarat-syarat berikut:
#
# Berhasil menjual 1000 produk
#
# memiliki feedback positif > 600
#
#
#
# Buatlah syntax nested conditional statement (if di dalam if) yang sesuai dengan kasus tersebut. Kemudian uji coba hasil nya dengan case sebagai berikut:
#
# sold = 1020
#
# pos_feed = 575

# %%
sold = 1000
positif > 600

if sold >= 1000:
    sellernya = 'premium'
    if positif > 600:
        sellernyaa = 'premium'
        result = 'premium'
    else:
        Sellernyaa = 'not premium'
        result = 'not premium'
else:
    sellernya = 'not premium'
    if positif > 600:
        Sellernyaa = 'not premium'
        result = 'not premium'
    else:
        Sellernyaa = 'not premium'
        result = 'not premium'
print(result)
# Out:
# not premium

# %%
sold = 1020
pos_feed = 525

if sold >= 1000:
    seller_1 = 'premium'
    if pos_feed > 525:
        seller_2 = 'premium'
        result = 'premium'
    else:
        Seller_2 = 'not premium'
        result = 'not premium'
else:
    seller_1 = 'not premium'
    if positif > 525:
        seller_2 = 'not premium'
        result = 'not premium'
    else:
        seller_2 = 'not premium'
        result = 'not premium'
print(result)
# Out:
# not premium

# %% [markdown]
# Buatlah syntax IF untuk melakukan pengecekan apakah variabel kategori1 ada di dalam list kategori, dimana kategori1 = 'Fashion Pria' list_kategori = ['Handphone', 'Sepeda', 'Makanan', 'Fashion Wanita']
#
# (TRUE/FALSE)

# %%
kategori1 = 'Fashion Pria' 
list_kategori = ['Handphone', 'Sepeda', 'Makanan', 'Fashion Wanita']

if kategori1 in list_kategori:
    result = True
else: 
        result = False

print(result)
# Out:
# False

# %%
import numpy as np
import pandas as pd

# %%
df_monthly_order = pd.read_csv(r'F:\COURSE\RAKAMIN\WEEK 6\monthly_rakamin_customer_order.csv')
df_monthly_order
# Out:
#     order_month       full_name   user_id         phone           city  \
# 0    2018-01-01   Ahmad Budiman  10000011  628785222211  Jakarta Pusat
# 1    2018-01-01      Azzam Haqq  10000012  628785222212       Surabaya
# 2    2018-01-01    Amrina Putri  10000013  628785222213  Jakarta Pusat
# 3    2018-01-01       Aan Utama  10000014  628785222214          Medan
# 4    2018-01-01        Adam Adi  10000015  628785222215  Jakarta Timur
# ..          ...             ...       ...           ...            ...
# 332  2022-06-01       Faruq Adi  10000030  628567812319       Makassar
# 333  2022-06-01       Abrar Adi  10000053  628223411218       Surabaya
# 334  2022-06-01    Johan Imawan  10000054  628223412323     Balikpapan
# 335  2022-06-01  Muhammad Ammar  10000055  628223412111       Surabaya
# 336  2022-05-01  Dodo Putro Aji  10000023  628567812312       Surabaya
#
#              province                   email  total_order  total_gmv  \
# ...

# %% [markdown]
# Menggunakan dataset monthly_rakamin_customer_order, tambahkan kolom is_higher_gmv dengan logik jika
#
#
#
# Total GMV lebih besar dari rata-rata GMV bulanan customer maka True namun jika tidak maka False
#
#
#
# Hint: Buat dataframe baru terlebih dulu dengan menggunakan fungsi Group by kemudian di merge / gunakan fungsi .transform()

# %%
#df_monthly_order['mean GMV'] = df['total GMV'].mean()
df_mean = df_monthly_order.groupby(['order_month'])['total_gmv'].mean().reset_index()
df_mean = df_mean.rename(columns = { 'total_gmv' : 'avg_gmv'})
df_merge = df_monthly_order.merge(df_mean,
                             # left_on = ['df_monthly_order'],
                              on = ['order_month'],
                              how = 'inner'
 )

df_merge['is_higher_gmv'] = np.where(df_merge['total_gmv'] > df_merge['avg_gmv'], True, False)
df_merge
# Out:
#     order_month       full_name   user_id         phone           city  \
# 0    2018-01-01   Ahmad Budiman  10000011  628785222211  Jakarta Pusat
# 1    2018-01-01      Azzam Haqq  10000012  628785222212       Surabaya
# 2    2018-01-01    Amrina Putri  10000013  628785222213  Jakarta Pusat
# 3    2018-01-01       Aan Utama  10000014  628785222214          Medan
# 4    2018-01-01        Adam Adi  10000015  628785222215  Jakarta Timur
# ..          ...             ...       ...           ...            ...
# 332  2022-06-01      Fawwaz Aji  10000029  628567812318           Solo
# 333  2022-06-01       Faruq Adi  10000030  628567812319       Makassar
# 334  2022-06-01       Abrar Adi  10000053  628223411218       Surabaya
# 335  2022-06-01    Johan Imawan  10000054  628223412323     Balikpapan
# 336  2022-06-01  Muhammad Ammar  10000055  628223412111       Surabaya
#
#              province                   email  total_order  total_gmv  \
# ...

# %%
# Out:
#     order_month       full_name   user_id         phone           city  \
# 0    2018-01-01   Ahmad Budiman  10000011  628785222211  Jakarta Pusat
# 1    2018-01-01      Azzam Haqq  10000012  628785222212       Surabaya
# 2    2018-01-01    Amrina Putri  10000013  628785222213  Jakarta Pusat
# 3    2018-01-01       Aan Utama  10000014  628785222214          Medan
# 4    2018-01-01        Adam Adi  10000015  628785222215  Jakarta Timur
# ..          ...             ...       ...           ...            ...
# 332  2022-06-01      Fawwaz Aji  10000029  628567812318           Solo
# 333  2022-06-01       Faruq Adi  10000030  628567812319       Makassar
# 334  2022-06-01       Abrar Adi  10000053  628223411218       Surabaya
# 335  2022-06-01    Johan Imawan  10000054  628223412323     Balikpapan
# 336  2022-06-01  Muhammad Ammar  10000055  628223412111       Surabaya
#
#              province                   email  total_order  total_gmv  \
# ...

# %%
df_monthly_order
# Out:
#     order_month       full_name   user_id         phone           city  \
# 0    2018-01-01   Ahmad Budiman  10000011  628785222211  Jakarta Pusat
# 1    2018-01-01      Azzam Haqq  10000012  628785222212       Surabaya
# 2    2018-01-01    Amrina Putri  10000013  628785222213  Jakarta Pusat
# 3    2018-01-01       Aan Utama  10000014  628785222214          Medan
# 4    2018-01-01        Adam Adi  10000015  628785222215  Jakarta Timur
# ..          ...             ...       ...           ...            ...
# 332  2022-06-01       Faruq Adi  10000030  628567812319       Makassar
# 333  2022-06-01       Abrar Adi  10000053  628223411218       Surabaya
# 334  2022-06-01    Johan Imawan  10000054  628223412323     Balikpapan
# 335  2022-06-01  Muhammad Ammar  10000055  628223412111       Surabaya
# 336  2022-05-01  Dodo Putro Aji  10000023  628567812312       Surabaya
#
#              province                   email  total_order  total_gmv  \
# ...

# %% [markdown]
# Team bisnis akan akan memberikan voucher bagi customer yang diindikasikan berpotensi churn di bulan depan. Berikut kriteria churn bulan depan.
#
# recency > 60
#
# frequent < 2
#
# monetary < 125000
#
# Gunakan nested conditional statement, agar kita bisa mengetahui kondisi setiap syarat!
#
# Lakukan uji coba pada 2 kondisi bebas! Nice to have reading RFM Analysis!

# %%
recency = 60
frequent = 2
monetary < 125000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9680\39348836.py in <module>
#       1 recency = 60
#       2 frequent = 2
# ----> 3 monetary < 125000
#
# NameError: name 'monetary' is not defined

# %%
if recency >= 60:
    syarat1 = True
    if frequent <= 2:
        syarat2 = True
        result = 'churn'
#    if monetary < 125000:
#        syarat3 = True
#        result = 'churn'
    else:
        syarat2 = False
        result = 'not churn'
#    else:
#        syarat3 = False
#        result = 'not churn'
else:
    syarat1 = False
    result = 'not churn'
    if frequent <= 2:
        syarat2 = True
    else:
        syarat2 = False
      #  syarat3 = False

print(syarat1)
# Out:
# True

# %%
recency >= 60
frequent <= 2
#monetary < 125000

if recency >= 60:
    syarat1 = True
    if frequent <= 2:
        syarat2 = True
        result = 'churn'
#    if monetary < 125000:
#        syarat3 = True
#        result = 'churn'
    else:
        syarat2 = False
        result = 'not churn'
#    else:
#        syarat3 = False
#        result = 'not churn'
else:
    syarat1 = False
    result = 'not churn'
    if frequent <= 2:
        syarat2 = True
    else:
        syarat2 = false
      #  syarat3 = False

print(syarat1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9680\226589725.py in <module>
# ----> 1 recency >= 60
#       2 frequent <= 2
#       3 #monetary < 125000
#       4
#       5 if recency >= 60:
#
# NameError: name 'recency' is not defined
